# %% [markdown]
# HOW TO RUN :
# 1. DOWNLOAD THE DATA FILES FROM THE GIVEN LINK IN YOUR GOOGLE DRIVE:
# https://drive.google.com/drive/folders/1TnHlcLsHW10mW-eHaMIyjspgJ8_mSMh-?usp=sharing
#               **or**
#
#  ** Add the folder as a shortcut to your drive**
#
# 2. Run the first code cell below to mount your google drive
# 3. From the files section of google colab create new folders and files named -
# Folders-
#         Hold time
#         Latencies
#         generated_fvectors
#         plots
# Files-
#        common_feat.txt
#
# 4. Run the cells normally to get the results

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob         #import all the required modules and library func!
import os
import string
from datetime import datetime
import numpy as np
import itertools
import random
from collections import Counter
from sklearn import svm
import pickle as pk
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


def feature_extraction(filename,rollnum):
    f = open(filename)
    f_list = f.readlines()
    f_list = [x[:-1] for x in f_list]
    if f_list[-1]=='\n':
      f_list.pop()
    
    KeyUps=[]    #Check for KEY UP events 
    for x in f_list:
      if 'KeyUp' in x :
        KeyUps.append(x)
    KeyDowns = [x for x in f_list if 'KeyDown' in x] #Check for keyDOwn Events
   
    time_upkeys =  [item[-26:-2]  for item in KeyUps]   #time Details of the up an down keys event
    time_downkeys =  [item[-26:-2]  for item in KeyDowns]
    
    try:
      pressed_letterup =  [item[-29].upper() for item in KeyUps]       #PRessed Key 
    except: 
      print('Error in ' )
    try:
      pressed_letterdown = [item[-29].upper() for item in KeyDowns]
    except:
      print('Error in ' )
    
    #GEt the latency and Hold time features !
    for i in range(0,len(time_upkeys)-1):
      t = i
      t1 = datetime.strptime(time_downkeys[i], "%d:%m:%Y:%H:%M:%S:%f")
     
      if pressed_letterup[t] != pressed_letterdown[i]:
        j = i
       
        if i == len(time_upkeys)-1:
          j = 0
        while j<len(time_upkeys)-1 and pressed_letterdown[i]!= pressed_letterup[j] and i!=len(time_upkeys)-1:
          j = j+1
        tj = datetime.strptime(time_upkeys[j], "%d:%m:%Y:%H:%M:%S:%f")
        k = i
        
        # Check if keyup is to the left of keydown
        if i == 0:
          k = len(time_upkeys)-1
        while k>=1 and pressed_letterdown[i]!= pressed_letterup[k] and i!=0:
          k = k-1
        tk = datetime.strptime(time_upkeys[k], "%d:%m:%Y:%H:%M:%S:%f")
       
        # Take the minimum of left and right distances if both distances can be valid
        if (tk-t1).total_seconds()>0 and (tj-t1).total_seconds()>0:
          if abs(j-i)<abs(i-k):
            t = j
          else:
            t = k
        elif (tk-t1).total_seconds()<0:
          t = j
        else:
          t = k
      t2 = datetime.strptime(time_upkeys[t], "%d:%m:%Y:%H:%M:%S:%f")
      
      # Latency calculation
      if i!=len(time_upkeys)-1:
        t3 = datetime.strptime(time_downkeys[i+1], "%d:%m:%Y:%H:%M:%S:%f")
        latency = t3-t1
        latency = latency.total_seconds()
        try:
          f = open("/content/Latencies/"+rollnum+pressed_letterdown[i] + pressed_letterdown[i+1] + ".txt", "a+")
        except:
          
          continue
        f.write(str(latency) + "\n")	
        f.close()
      
      # Hold time calculation
      hold_time = t2-t1
      hold_time = hold_time.total_seconds()
      try:
        f = open("/content/Hold times/" + rollnum+pressed_letterdown[i] + ".txt", "a+")
      except:
        continue
      
      f.write(str(hold_time) + "\n")	
      f.close()


def common_features():
  f = open("/content/common_feat.txt", "w+")

  names = list()

  file_count = 9         # (Data of 9 users only available  [5 group 7][4 group 8])
  for filename in glob.glob('/content/Latencies/*'):
    names.append(filename.split('/')[-1][9:])
  for filename in glob.glob('/content/Hold times/*'):
    names.append(filename.split('/')[-1][9:])
  c = Counter(names)
  single_textnames = [i + '.txt' for i in (string.ascii_uppercase[:26])]
  double_textnames = [i+j+'.txt' for i in (string.ascii_uppercase[:26]) for j in (string.ascii_uppercase[:26])]
  textnames = single_textnames+double_textnames

  for name in textnames:
	  if (c[name] == file_count):		# if this number is equal to the number of roll numbers, it is present for all users, and belongs to the common subset
		  f.write("%s\n" % name)		# hence, write out as part of the common subset
  f.close()

def random_line(afile):
    line = next(afile)
    for num, aline in enumerate(afile, 2):
      if random.randrange(num): continue
      line = aline
    return line

def feature_vector():
  f = open('/content/common_feat.txt','r')
  f_list = f.readlines()
  f_list = [x[:-1] for x in f_list]
  if f_list[-1]=='\n':
      f_list.pop()

  rolls = [f.name for f in os.scandir('/content/drive/MyDrive/data') if f.is_dir()]
  random_flist = []
  random_flist2= []
  random_indice = random.sample(range(0, 265), 24)  #24?
  random_index2 = random.sample(range(0, 265), 24)        #For Model 2 where diff sets of random features are selected !

  for ind in range(len(random_indice)):
    random_flist.append(f_list[random_indice[ind]])
    random_flist2.append(f_list[random_index2[ind]])

  print(random_flist)
  
  models=2;
  for mod in range(models):
    for rollnum in rolls:
      # Extracting the hold times and latencies from the files
      hold_list = glob.glob('/content/Latencies/*')
      lat_list = glob.glob('/content/Hold times/*')
      total_list = hold_list + lat_list
      random_file_list=[]
     
      # Common feature
      if mod==0:
        for i in range (len(random_flist)):
          random_file_list.append('/content/Latencies/'+rollnum+random_flist[i])
          random_file_list.append('/content/Hold times/'+rollnum+random_flist[i])
      else:
        for i in range (len(random_flist2)):
          random_file_list.append('/content/Latencies/'+rollnum+random_flist2[i])
          random_file_list.append('/content/Hold times/'+rollnum+random_flist2[i])

      

      total_list = [x for x in random_file_list if x in total_list]
      l = []
      feat_vec = np.zeros((256,24))  #24 random features being taken
      # Parsing the files to generate l
      for i in range(256):
          file_no=0
          for x in total_list:            
              inner_list = []
              try:
                  with open(x) as f:
                      line = random_line(f)
                  feat_vec[i,file_no] = line
              except:
                  with open(x) as f:
                      line=random_line(f)
                      feat_vec[i,file_no] = line
              file_no+=1
    
      with open('/content/generated_fvectors/'+rollnum+'_'+str(mod)+'.pickle', 'wb') as f:
          pickle.dump(feat_vec, f)

def calc_tp(y_pred_test,Y_test):
  tp=0
  for i in range(len(y_pred_test)):
    if(y_pred_test[i]==Y_test[i] and y_pred_test[i]==1):
      tp=tp+1
  return tp
  

def calc_fp(y_pred_test,Y_test):
  fp=0
  for i in range(len(y_pred_test)):
    if(y_pred_test[i]!=Y_test[i] and y_pred_test[i]==1):
      fp=fp+1
  return fp

def calc_tn(y_pred_test,Y_test):
  tn=0
  for i in range(len(y_pred_test)):
    if(y_pred_test[i]==Y_test[i] and y_pred_test[i]==-1):
      tn=tn+1
  return tn

def calc_fn(y_pred_test,Y_test):
  fn=0
  for i in range(len(y_pred_test)):
    if(y_pred_test[i]!=Y_test[i] and y_pred_test[i]==-1):
      fn=fn+1
  return fn

def calc_metrics(tp,fp,tn,fn):
  precision = (tp*100)/(tp+fp+1e-7)
  recall = (tp*100)/(tp+fn+1e-7)
  specificity = (tn*100)/(tn+fp+1e-7)
  accuracy = 0.5*(tp*100.0/(tp+fn+1e-7)+tn*100.0/(tn+fp+1e-7))
  testing_error = 100-accuracy
  return precision,recall,specificity,accuracy,testing_error


def svm_one_class(X_train,X_test,Y_test):
    nu = np.logspace(-3,0,10)
    #gamma =np.np.linspace(0.01,0.1,5)    #uncomment for gamma variations
    #nu=10e-3         #uncomment for gamma variations
    test_acc = []
    for k in range(len(nu)):
        clf = svm.OneClassSVM(gamma='auto', kernel="rbf", nu = nu[k])
        clf.fit(X_train)
        y_pred_train = clf.predict(X_train)
        y_pred_test = clf.predict(X_test)
        n_error_train = y_pred_train[y_pred_train == -1].size     #No of training mislassifiations
        positive_user = y_pred_test[y_pred_test == Y_test].size       #No of Predictions that the user is i
        negative_user = y_pred_test[y_pred_test != Y_test].size       #No of Predictions that the user is not i
      
        tp=calc_tp(y_pred_test,Y_test)
        fp=calc_fp(y_pred_test,Y_test)
        tn=calc_tn(y_pred_test,Y_test)
        fn=calc_fn(y_pred_test,Y_test)

        precision,recall,specificity,accuracy,testing_error = calc_metrics(tp,fp,tn,fn)
        #print ("Nu : %f" %nu[k])
        print("Training Dataset Size : %s" %y_pred_train.size)
        print("No of Training Misclassifications : %s" %n_error_train)
        print("Training Error : %.2f percent" %((n_error_train*100)/y_pred_train.size))
        print("Testing Dataset Size : %s" %Y_test.size)
        print("Correct Decissions: %s" %positive_user)
        print("Incorrect Decissions: %s" %negative_user)
        print("Testing Accuracy: %.2f percent" %(accuracy))
        print("Testing Error: %.2f percent" %(testing_error))
        print("Precision: %.2f percent" %(precision))
        print("Recall: %.2f percent" %(recall))
        print("Specificity: %.2f percent" %(specificity))
        print()
        test_acc.append(accuracy)
    return accuracy,precision, recall, test_acc

def plot(average_test_acc,roll):
    nu = np.logspace(-3,0,10)
    #gamma = np.linspace(0.01,0.1,5)
    ax = plt.axes()
    ax.xaxis.set_major_locator(plt.MaxNLocator(11))
    ax.xaxis.set_minor_locator(plt.MaxNLocator(100))
    ax.yaxis.set_major_locator(plt.MaxNLocator(11))
    ax.yaxis.set_minor_locator(plt.MaxNLocator(100))

    plt.xscale("log")       #Comment for gamma plots
    plt.plot(nu,average_test_acc, label = roll)
    ax.grid(which = 'major', linestyle='-', linewidth = 0.9, alpha=1.0)
    ax.grid(which = 'minor', linestyle=':', linewidth = 0.6, alpha=0.8)
    plt.xticks(rotation='vertical')
    plt.xlabel("Nu")
    plt.ylabel("average accuracy")
    plt.legend(loc='upper center', bbox_to_anchor=(0.8, 1.25), ncol=4)
    plt.savefig( "/content/plots/" + roll + '.png',dpi=500, bbox_inches = 'tight')



def main():
    for name in glob.glob('/content/drive/MyDrive/data/*/*.txt'):
      roll_num=name.split('/')[-2]
      #print(roll_num)
      feature_extraction(name,roll_num)
    common_features()
    feature_vector()
    n = 0     #No of people
    data=[]    #Data Set
    roll=[]

    rollnums=[f.name for f in os.scandir('/content/drive/MyDrive/data') if f.is_dir()]
    for rollnum in rollnums:
        n=n+1
        roll.append(rollnum)
        with open('/content/generated_fvectors/'+rollnum+'_0.pickle', "rb") as input_file:
            ef = pk.load(input_file)
            ck=[]
            for item in ef:
                ck.append(item)
            data.append(np.array(ck))


    for i in range(n):	# n is the number of roll numbers (users)
        #concatinate all the list together for testing as all column size same
        if(i==0):
            test=data[1]
            for k in range (2,n):
                test=np.vstack((test,data[k]))                     #Stack the datasets together
        else:
            test=data[0]
            for k in range (1,n):
                if(k!=i):
                    test=np.vstack((test,data[k]))                 #Stack the datasets together

        print("-------------------------------------------------------")
        print("For User %s" %roll[i])
        total_test_acc = []
        average_test_acc = []
        for j in range (5):
                                                    #5 Fold cross validation
            print("Validation Fold %s:" %(j+1))
            data_train=data[i]       
            np.random.shuffle(data_train)
            sz=int(0.2*data_train.shape[0])+1
            data_train_final=data_train[:-sz]                     #Discarding last 5% entries for training and add them in tesing
            data_test_final=data_train[-sz:]
    	    
            scaler = StandardScaler()
            data_train_final = scaler.fit_transform(data_train_final)

            pca = PCA(n_components = 8)
            data_train_final = pca.fit_transform(data_train_final)
            y=np.ones(sz)


            sz=int(0.05*data_train.shape[0])+1   
            #print(sz)           #No of test sample needed more for 80:20 ratio 80 authentic (same user) and 20 other users
            np.random.shuffle(test)                               
            data_test_final=np.vstack((data_test_final,test[:sz]))
            data_test_final = scaler.transform(data_test_final)
            data_test_final = pca.transform(data_test_final)
            z=-np.ones(sz)
            y_final=np.append(y,z)                       #Result vector for Testing
            accuracy,precision, recall, test_acc = svm_one_class(data_train_final,data_test_final,y_final)       # calling SVM function
            total_test_acc.append(test_acc)

        # print(total_test_error)    
        for k in range(len(test_acc)):
            average = 0
            for j in range(5):
                average = total_test_acc[j][k]+ average
            average = average/5
            average_test_acc.append(average)
        plot(average_test_acc,roll[i])

if __name__=="__main__":
    main()
# Out:
# ['C.txt', 'AI.txt', 'RO.txt', 'B.txt', 'P.txt', 'TI.txt', 'IM.txt', 'UG.txt', 'WA.txt', 'V.txt', 'CO.txt', 'OW.txt', 'ML.txt', 'DO.txt', 'UR.txt', 'IP.txt', 'LC.txt', 'OD.txt', 'OU.txt', 'IG.txt', 'CU.txt', 'AY.txt', 'OM.txt', 'EA.txt']
# -------------------------------------------------------
# For User 18EC10062
# Validation Fold 1:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 32
# Training Error : 15.69 percent
# Testing Dataset Size : 65
# Correct Decissions: 46
# Incorrect Decissions: 19
# Testing Accuracy: 73.08 percent
# Testing Error: 26.92 percent
# Precision: 92.31 percent
# Recall: 69.23 percent
# Specificity: 76.92 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 31
# Training Error : 15.20 percent
# Testing Dataset Size : 65
# Correct Decissions: 48
# Incorrect Decissions: 17
# Testing Accuracy: 75.00 percent
# Testing Error: 25.00 percent
# Precision: 92.68 percent
# Recall: 73.08 percent
# Specificity: 76.92 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 30
# Training Error : 14.71 percent
# Testing Dataset Size : 65
# Correct Decissions: 48
# Incorrect Decissions: 17
# Testing Accuracy: 75.00 percent
# Testing Error: 25.00 percent
# Precision: 92.68 percent
# Recall: 73.08 percent
# Specificity: 76.92 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 34
# Training Error : 16.67 percent
# Testing Dataset Size : 65
# Correct Decissions: 48
# Incorrect Decissions: 17
# Testing Accuracy: 75.00 percent
# Testing Error: 25.00 percent
# Precision: 92.68 percent
# Recall: 73.08 percent
# Specificity: 76.92 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 26
# Training Error : 12.75 percent
# Testing Dataset Size : 65
# Correct Decissions: 48
# Incorrect Decissions: 17
# Testing Accuracy: 75.00 percent
# Testing Error: 25.00 percent
# Precision: 92.68 percent
# Recall: 73.08 percent
# Specificity: 76.92 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 27
# Training Error : 13.24 percent
# Testing Dataset Size : 65
# Correct Decissions: 48
# Incorrect Decissions: 17
# Testing Accuracy: 75.00 percent
# Testing Error: 25.00 percent
# Precision: 92.68 percent
# Recall: 73.08 percent
# Specificity: 76.92 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 32
# Training Error : 15.69 percent
# Testing Dataset Size : 65
# Correct Decissions: 48
# Incorrect Decissions: 17
# Testing Accuracy: 75.00 percent
# Testing Error: 25.00 percent
# Precision: 92.68 percent
# Recall: 73.08 percent
# Specificity: 76.92 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 43
# Training Error : 21.08 percent
# Testing Dataset Size : 65
# Correct Decissions: 45
# Incorrect Decissions: 20
# Testing Accuracy: 72.12 percent
# Testing Error: 27.88 percent
# Precision: 92.11 percent
# Recall: 67.31 percent
# Specificity: 76.92 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 95
# Training Error : 46.57 percent
# Testing Dataset Size : 65
# Correct Decissions: 43
# Incorrect Decissions: 22
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 96.87 percent
# Recall: 59.62 percent
# Specificity: 92.31 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# Validation Fold 2:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 42
# Training Error : 20.59 percent
# Testing Dataset Size : 65
# Correct Decissions: 49
# Incorrect Decissions: 16
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 97.37 percent
# Recall: 71.15 percent
# Specificity: 92.31 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 35
# Training Error : 17.16 percent
# Testing Dataset Size : 65
# Correct Decissions: 49
# Incorrect Decissions: 16
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 97.37 percent
# Recall: 71.15 percent
# Specificity: 92.31 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 27
# Training Error : 13.24 percent
# Testing Dataset Size : 65
# Correct Decissions: 49
# Incorrect Decissions: 16
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 97.37 percent
# Recall: 71.15 percent
# Specificity: 92.31 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 34
# Training Error : 16.67 percent
# Testing Dataset Size : 65
# Correct Decissions: 49
# Incorrect Decissions: 16
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 97.37 percent
# Recall: 71.15 percent
# Specificity: 92.31 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 36
# Training Error : 17.65 percent
# Testing Dataset Size : 65
# Correct Decissions: 49
# Incorrect Decissions: 16
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 97.37 percent
# Recall: 71.15 percent
# Specificity: 92.31 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 30
# Training Error : 14.71 percent
# Testing Dataset Size : 65
# Correct Decissions: 49
# Incorrect Decissions: 16
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 97.37 percent
# Recall: 71.15 percent
# Specificity: 92.31 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 49
# Incorrect Decissions: 16
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 97.37 percent
# Recall: 71.15 percent
# Specificity: 92.31 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 49
# Training Error : 24.02 percent
# Testing Dataset Size : 65
# Correct Decissions: 48
# Incorrect Decissions: 17
# Testing Accuracy: 80.77 percent
# Testing Error: 19.23 percent
# Precision: 97.30 percent
# Recall: 69.23 percent
# Specificity: 92.31 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 95
# Training Error : 46.57 percent
# Testing Dataset Size : 65
# Correct Decissions: 42
# Incorrect Decissions: 23
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 100.00 percent
# Recall: 55.77 percent
# Specificity: 100.00 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# Validation Fold 3:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 50
# Incorrect Decissions: 15
# Testing Accuracy: 76.92 percent
# Testing Error: 23.08 percent
# Precision: 93.02 percent
# Recall: 76.92 percent
# Specificity: 76.92 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 35
# Training Error : 17.16 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 30
# Training Error : 14.71 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 32
# Training Error : 15.69 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 29
# Training Error : 14.22 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 28
# Training Error : 13.73 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 32
# Training Error : 15.69 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 47
# Training Error : 23.04 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 93
# Training Error : 45.59 percent
# Testing Dataset Size : 65
# Correct Decissions: 41
# Incorrect Decissions: 24
# Testing Accuracy: 68.27 percent
# Testing Error: 31.73 percent
# Precision: 91.18 percent
# Recall: 59.62 percent
# Specificity: 76.92 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# Validation Fold 4:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 36
# Training Error : 17.65 percent
# Testing Dataset Size : 65
# Correct Decissions: 47
# Incorrect Decissions: 18
# Testing Accuracy: 76.92 percent
# Testing Error: 23.08 percent
# Precision: 94.74 percent
# Recall: 69.23 percent
# Specificity: 84.62 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 31
# Training Error : 15.20 percent
# Testing Dataset Size : 65
# Correct Decissions: 47
# Incorrect Decissions: 18
# Testing Accuracy: 76.92 percent
# Testing Error: 23.08 percent
# Precision: 94.74 percent
# Recall: 69.23 percent
# Specificity: 84.62 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 47
# Incorrect Decissions: 18
# Testing Accuracy: 76.92 percent
# Testing Error: 23.08 percent
# Precision: 94.74 percent
# Recall: 69.23 percent
# Specificity: 84.62 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 32
# Training Error : 15.69 percent
# Testing Dataset Size : 65
# Correct Decissions: 47
# Incorrect Decissions: 18
# Testing Accuracy: 76.92 percent
# Testing Error: 23.08 percent
# Precision: 94.74 percent
# Recall: 69.23 percent
# Specificity: 84.62 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 32
# Training Error : 15.69 percent
# Testing Dataset Size : 65
# Correct Decissions: 47
# Incorrect Decissions: 18
# Testing Accuracy: 76.92 percent
# Testing Error: 23.08 percent
# Precision: 94.74 percent
# Recall: 69.23 percent
# Specificity: 84.62 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 30
# Training Error : 14.71 percent
# Testing Dataset Size : 65
# Correct Decissions: 47
# Incorrect Decissions: 18
# Testing Accuracy: 76.92 percent
# Testing Error: 23.08 percent
# Precision: 94.74 percent
# Recall: 69.23 percent
# Specificity: 84.62 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 32
# Training Error : 15.69 percent
# Testing Dataset Size : 65
# Correct Decissions: 47
# Incorrect Decissions: 18
# Testing Accuracy: 76.92 percent
# Testing Error: 23.08 percent
# Precision: 94.74 percent
# Recall: 69.23 percent
# Specificity: 84.62 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 47
# Training Error : 23.04 percent
# Testing Dataset Size : 65
# Correct Decissions: 47
# Incorrect Decissions: 18
# Testing Accuracy: 76.92 percent
# Testing Error: 23.08 percent
# Precision: 94.74 percent
# Recall: 69.23 percent
# Specificity: 84.62 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 96
# Training Error : 47.06 percent
# Testing Dataset Size : 65
# Correct Decissions: 38
# Incorrect Decissions: 27
# Testing Accuracy: 68.27 percent
# Testing Error: 31.73 percent
# Precision: 93.10 percent
# Recall: 51.92 percent
# Specificity: 84.62 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# Validation Fold 5:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 35
# Training Error : 17.16 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 86.54 percent
# Testing Error: 13.46 percent
# Precision: 100.00 percent
# Recall: 73.08 percent
# Specificity: 100.00 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 39
# Training Error : 19.12 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 86.54 percent
# Testing Error: 13.46 percent
# Precision: 100.00 percent
# Recall: 73.08 percent
# Specificity: 100.00 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 34
# Training Error : 16.67 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 86.54 percent
# Testing Error: 13.46 percent
# Precision: 100.00 percent
# Recall: 73.08 percent
# Specificity: 100.00 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 31
# Training Error : 15.20 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 86.54 percent
# Testing Error: 13.46 percent
# Precision: 100.00 percent
# Recall: 73.08 percent
# Specificity: 100.00 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 34
# Training Error : 16.67 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 86.54 percent
# Testing Error: 13.46 percent
# Precision: 100.00 percent
# Recall: 73.08 percent
# Specificity: 100.00 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 34
# Training Error : 16.67 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 86.54 percent
# Testing Error: 13.46 percent
# Precision: 100.00 percent
# Recall: 73.08 percent
# Specificity: 100.00 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 86.54 percent
# Testing Error: 13.46 percent
# Precision: 100.00 percent
# Recall: 73.08 percent
# Specificity: 100.00 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 44
# Training Error : 21.57 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 86.54 percent
# Testing Error: 13.46 percent
# Precision: 100.00 percent
# Recall: 73.08 percent
# Specificity: 100.00 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 94
# Training Error : 46.08 percent
# Testing Dataset Size : 65
# Correct Decissions: 43
# Incorrect Decissions: 22
# Testing Accuracy: 78.85 percent
# Testing Error: 21.15 percent
# Precision: 100.00 percent
# Recall: 57.69 percent
# Specificity: 100.00 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# -------------------------------------------------------
# For User 18EC35034
# Validation Fold 1:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 41
# Training Error : 20.10 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 91.49 percent
# Recall: 82.69 percent
# Specificity: 69.23 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 29
# Training Error : 14.22 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 91.49 percent
# Recall: 82.69 percent
# Specificity: 69.23 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 91.49 percent
# Recall: 82.69 percent
# Specificity: 69.23 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 91.49 percent
# Recall: 82.69 percent
# Specificity: 69.23 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 91.49 percent
# Recall: 82.69 percent
# Specificity: 69.23 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 26
# Training Error : 12.75 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 91.49 percent
# Recall: 82.69 percent
# Specificity: 69.23 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 91.49 percent
# Recall: 82.69 percent
# Specificity: 69.23 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 46
# Training Error : 22.55 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 91.49 percent
# Recall: 82.69 percent
# Specificity: 69.23 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 95
# Training Error : 46.57 percent
# Testing Dataset Size : 65
# Correct Decissions: 42
# Incorrect Decissions: 23
# Testing Accuracy: 69.23 percent
# Testing Error: 30.77 percent
# Precision: 91.43 percent
# Recall: 61.54 percent
# Specificity: 76.92 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# Validation Fold 2:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 36
# Training Error : 17.65 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 75.00 percent
# Testing Error: 25.00 percent
# Precision: 91.30 percent
# Recall: 80.77 percent
# Specificity: 69.23 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 36
# Training Error : 17.65 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 91.49 percent
# Recall: 82.69 percent
# Specificity: 69.23 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 29
# Training Error : 14.22 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 91.49 percent
# Recall: 82.69 percent
# Specificity: 69.23 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 91.49 percent
# Recall: 82.69 percent
# Specificity: 69.23 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 36
# Training Error : 17.65 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 91.49 percent
# Recall: 82.69 percent
# Specificity: 69.23 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 35
# Training Error : 17.16 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 91.49 percent
# Recall: 82.69 percent
# Specificity: 69.23 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 91.49 percent
# Recall: 82.69 percent
# Specificity: 69.23 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 48
# Training Error : 23.53 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 91.49 percent
# Recall: 82.69 percent
# Specificity: 69.23 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 95
# Training Error : 46.57 percent
# Testing Dataset Size : 65
# Correct Decissions: 43
# Incorrect Decissions: 22
# Testing Accuracy: 70.19 percent
# Testing Error: 29.81 percent
# Precision: 91.67 percent
# Recall: 63.46 percent
# Specificity: 76.92 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# Validation Fold 3:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 35
# Training Error : 17.16 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 35
# Training Error : 17.16 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 32
# Training Error : 15.69 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 36
# Training Error : 17.65 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 31
# Training Error : 15.20 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 32
# Training Error : 15.69 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 50
# Training Error : 24.51 percent
# Testing Dataset Size : 65
# Correct Decissions: 49
# Incorrect Decissions: 16
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 92.86 percent
# Recall: 75.00 percent
# Specificity: 76.92 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 93
# Training Error : 45.59 percent
# Testing Dataset Size : 65
# Correct Decissions: 41
# Incorrect Decissions: 24
# Testing Accuracy: 74.04 percent
# Testing Error: 25.96 percent
# Precision: 96.67 percent
# Recall: 55.77 percent
# Specificity: 92.31 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# Validation Fold 4:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 49
# Incorrect Decissions: 16
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 92.86 percent
# Recall: 75.00 percent
# Specificity: 76.92 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 32
# Training Error : 15.69 percent
# Testing Dataset Size : 65
# Correct Decissions: 50
# Incorrect Decissions: 15
# Testing Accuracy: 76.92 percent
# Testing Error: 23.08 percent
# Precision: 93.02 percent
# Recall: 76.92 percent
# Specificity: 76.92 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 36
# Training Error : 17.65 percent
# Testing Dataset Size : 65
# Correct Decissions: 50
# Incorrect Decissions: 15
# Testing Accuracy: 76.92 percent
# Testing Error: 23.08 percent
# Precision: 93.02 percent
# Recall: 76.92 percent
# Specificity: 76.92 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 38
# Training Error : 18.63 percent
# Testing Dataset Size : 65
# Correct Decissions: 50
# Incorrect Decissions: 15
# Testing Accuracy: 76.92 percent
# Testing Error: 23.08 percent
# Precision: 93.02 percent
# Recall: 76.92 percent
# Specificity: 76.92 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 35
# Training Error : 17.16 percent
# Testing Dataset Size : 65
# Correct Decissions: 50
# Incorrect Decissions: 15
# Testing Accuracy: 76.92 percent
# Testing Error: 23.08 percent
# Precision: 93.02 percent
# Recall: 76.92 percent
# Specificity: 76.92 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 34
# Training Error : 16.67 percent
# Testing Dataset Size : 65
# Correct Decissions: 50
# Incorrect Decissions: 15
# Testing Accuracy: 76.92 percent
# Testing Error: 23.08 percent
# Precision: 93.02 percent
# Recall: 76.92 percent
# Specificity: 76.92 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 29
# Training Error : 14.22 percent
# Testing Dataset Size : 65
# Correct Decissions: 50
# Incorrect Decissions: 15
# Testing Accuracy: 76.92 percent
# Testing Error: 23.08 percent
# Precision: 93.02 percent
# Recall: 76.92 percent
# Specificity: 76.92 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 46
# Training Error : 22.55 percent
# Testing Dataset Size : 65
# Correct Decissions: 49
# Incorrect Decissions: 16
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 92.86 percent
# Recall: 75.00 percent
# Specificity: 76.92 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 97
# Training Error : 47.55 percent
# Testing Dataset Size : 65
# Correct Decissions: 40
# Incorrect Decissions: 25
# Testing Accuracy: 67.31 percent
# Testing Error: 32.69 percent
# Precision: 90.91 percent
# Recall: 57.69 percent
# Specificity: 76.92 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# Validation Fold 5:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 37
# Training Error : 18.14 percent
# Testing Dataset Size : 65
# Correct Decissions: 56
# Incorrect Decissions: 9
# Testing Accuracy: 82.69 percent
# Testing Error: 17.31 percent
# Precision: 93.88 percent
# Recall: 88.46 percent
# Specificity: 76.92 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 37
# Training Error : 18.14 percent
# Testing Dataset Size : 65
# Correct Decissions: 57
# Incorrect Decissions: 8
# Testing Accuracy: 83.65 percent
# Testing Error: 16.35 percent
# Precision: 94.00 percent
# Recall: 90.38 percent
# Specificity: 76.92 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 37
# Training Error : 18.14 percent
# Testing Dataset Size : 65
# Correct Decissions: 57
# Incorrect Decissions: 8
# Testing Accuracy: 83.65 percent
# Testing Error: 16.35 percent
# Precision: 94.00 percent
# Recall: 90.38 percent
# Specificity: 76.92 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 30
# Training Error : 14.71 percent
# Testing Dataset Size : 65
# Correct Decissions: 57
# Incorrect Decissions: 8
# Testing Accuracy: 83.65 percent
# Testing Error: 16.35 percent
# Precision: 94.00 percent
# Recall: 90.38 percent
# Specificity: 76.92 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 34
# Training Error : 16.67 percent
# Testing Dataset Size : 65
# Correct Decissions: 57
# Incorrect Decissions: 8
# Testing Accuracy: 83.65 percent
# Testing Error: 16.35 percent
# Precision: 94.00 percent
# Recall: 90.38 percent
# Specificity: 76.92 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 31
# Training Error : 15.20 percent
# Testing Dataset Size : 65
# Correct Decissions: 57
# Incorrect Decissions: 8
# Testing Accuracy: 83.65 percent
# Testing Error: 16.35 percent
# Precision: 94.00 percent
# Recall: 90.38 percent
# Specificity: 76.92 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 34
# Training Error : 16.67 percent
# Testing Dataset Size : 65
# Correct Decissions: 57
# Incorrect Decissions: 8
# Testing Accuracy: 83.65 percent
# Testing Error: 16.35 percent
# Precision: 94.00 percent
# Recall: 90.38 percent
# Specificity: 76.92 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 43
# Training Error : 21.08 percent
# Testing Dataset Size : 65
# Correct Decissions: 57
# Incorrect Decissions: 8
# Testing Accuracy: 83.65 percent
# Testing Error: 16.35 percent
# Precision: 94.00 percent
# Recall: 90.38 percent
# Specificity: 76.92 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 93
# Training Error : 45.59 percent
# Testing Dataset Size : 65
# Correct Decissions: 47
# Incorrect Decissions: 18
# Testing Accuracy: 74.04 percent
# Testing Error: 25.96 percent
# Precision: 92.50 percent
# Recall: 71.15 percent
# Specificity: 76.92 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:263: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# -------------------------------------------------------
# For User 18EC10073
# Validation Fold 1:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 36
# Training Error : 17.65 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 80.77 percent
# Testing Error: 19.23 percent
# Precision: 95.24 percent
# Recall: 76.92 percent
# Specificity: 84.62 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 41
# Training Error : 20.10 percent
# Testing Dataset Size : 65
# Correct Decissions: 50
# Incorrect Decissions: 15
# Testing Accuracy: 79.81 percent
# Testing Error: 20.19 percent
# Precision: 95.12 percent
# Recall: 75.00 percent
# Specificity: 84.62 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 39
# Training Error : 19.12 percent
# Testing Dataset Size : 65
# Correct Decissions: 50
# Incorrect Decissions: 15
# Testing Accuracy: 79.81 percent
# Testing Error: 20.19 percent
# Precision: 95.12 percent
# Recall: 75.00 percent
# Specificity: 84.62 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 42
# Training Error : 20.59 percent
# Testing Dataset Size : 65
# Correct Decissions: 50
# Incorrect Decissions: 15
# Testing Accuracy: 79.81 percent
# Testing Error: 20.19 percent
# Precision: 95.12 percent
# Recall: 75.00 percent
# Specificity: 84.62 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 38
# Training Error : 18.63 percent
# Testing Dataset Size : 65
# Correct Decissions: 50
# Incorrect Decissions: 15
# Testing Accuracy: 79.81 percent
# Testing Error: 20.19 percent
# Precision: 95.12 percent
# Recall: 75.00 percent
# Specificity: 84.62 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 50
# Incorrect Decissions: 15
# Testing Accuracy: 79.81 percent
# Testing Error: 20.19 percent
# Precision: 95.12 percent
# Recall: 75.00 percent
# Specificity: 84.62 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 35
# Training Error : 17.16 percent
# Testing Dataset Size : 65
# Correct Decissions: 50
# Incorrect Decissions: 15
# Testing Accuracy: 79.81 percent
# Testing Error: 20.19 percent
# Precision: 95.12 percent
# Recall: 75.00 percent
# Specificity: 84.62 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 47
# Training Error : 23.04 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 80.77 percent
# Testing Error: 19.23 percent
# Precision: 95.24 percent
# Recall: 76.92 percent
# Specificity: 84.62 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 93
# Training Error : 45.59 percent
# Testing Dataset Size : 65
# Correct Decissions: 45
# Incorrect Decissions: 20
# Testing Accuracy: 80.77 percent
# Testing Error: 19.23 percent
# Precision: 100.00 percent
# Recall: 61.54 percent
# Specificity: 100.00 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# Validation Fold 2:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 38
# Training Error : 18.63 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 78.85 percent
# Testing Error: 21.15 percent
# Precision: 93.33 percent
# Recall: 80.77 percent
# Specificity: 76.92 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 30
# Training Error : 14.71 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 78.85 percent
# Testing Error: 21.15 percent
# Precision: 93.33 percent
# Recall: 80.77 percent
# Specificity: 76.92 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 31
# Training Error : 15.20 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 78.85 percent
# Testing Error: 21.15 percent
# Precision: 93.33 percent
# Recall: 80.77 percent
# Specificity: 76.92 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 78.85 percent
# Testing Error: 21.15 percent
# Precision: 93.33 percent
# Recall: 80.77 percent
# Specificity: 76.92 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 29
# Training Error : 14.22 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 78.85 percent
# Testing Error: 21.15 percent
# Precision: 93.33 percent
# Recall: 80.77 percent
# Specificity: 76.92 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 31
# Training Error : 15.20 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 78.85 percent
# Testing Error: 21.15 percent
# Precision: 93.33 percent
# Recall: 80.77 percent
# Specificity: 76.92 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 26
# Training Error : 12.75 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 78.85 percent
# Testing Error: 21.15 percent
# Precision: 93.33 percent
# Recall: 80.77 percent
# Specificity: 76.92 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 42
# Training Error : 20.59 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 78.85 percent
# Testing Error: 21.15 percent
# Precision: 93.33 percent
# Recall: 80.77 percent
# Specificity: 76.92 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 93
# Training Error : 45.59 percent
# Testing Dataset Size : 65
# Correct Decissions: 42
# Incorrect Decissions: 23
# Testing Accuracy: 69.23 percent
# Testing Error: 30.77 percent
# Precision: 91.43 percent
# Recall: 61.54 percent
# Specificity: 76.92 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# Validation Fold 3:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 36
# Training Error : 17.65 percent
# Testing Dataset Size : 65
# Correct Decissions: 45
# Incorrect Decissions: 20
# Testing Accuracy: 75.00 percent
# Testing Error: 25.00 percent
# Precision: 94.44 percent
# Recall: 65.38 percent
# Specificity: 84.62 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 28
# Training Error : 13.73 percent
# Testing Dataset Size : 65
# Correct Decissions: 45
# Incorrect Decissions: 20
# Testing Accuracy: 75.00 percent
# Testing Error: 25.00 percent
# Precision: 94.44 percent
# Recall: 65.38 percent
# Specificity: 84.62 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 30
# Training Error : 14.71 percent
# Testing Dataset Size : 65
# Correct Decissions: 45
# Incorrect Decissions: 20
# Testing Accuracy: 75.00 percent
# Testing Error: 25.00 percent
# Precision: 94.44 percent
# Recall: 65.38 percent
# Specificity: 84.62 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 30
# Training Error : 14.71 percent
# Testing Dataset Size : 65
# Correct Decissions: 45
# Incorrect Decissions: 20
# Testing Accuracy: 75.00 percent
# Testing Error: 25.00 percent
# Precision: 94.44 percent
# Recall: 65.38 percent
# Specificity: 84.62 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 31
# Training Error : 15.20 percent
# Testing Dataset Size : 65
# Correct Decissions: 45
# Incorrect Decissions: 20
# Testing Accuracy: 75.00 percent
# Testing Error: 25.00 percent
# Precision: 94.44 percent
# Recall: 65.38 percent
# Specificity: 84.62 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 35
# Training Error : 17.16 percent
# Testing Dataset Size : 65
# Correct Decissions: 45
# Incorrect Decissions: 20
# Testing Accuracy: 75.00 percent
# Testing Error: 25.00 percent
# Precision: 94.44 percent
# Recall: 65.38 percent
# Specificity: 84.62 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 29
# Training Error : 14.22 percent
# Testing Dataset Size : 65
# Correct Decissions: 45
# Incorrect Decissions: 20
# Testing Accuracy: 75.00 percent
# Testing Error: 25.00 percent
# Precision: 94.44 percent
# Recall: 65.38 percent
# Specificity: 84.62 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 44
# Training Error : 21.57 percent
# Testing Dataset Size : 65
# Correct Decissions: 44
# Incorrect Decissions: 21
# Testing Accuracy: 74.04 percent
# Testing Error: 25.96 percent
# Precision: 94.29 percent
# Recall: 63.46 percent
# Specificity: 84.62 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 93
# Training Error : 45.59 percent
# Testing Dataset Size : 65
# Correct Decissions: 41
# Incorrect Decissions: 24
# Testing Accuracy: 74.04 percent
# Testing Error: 25.96 percent
# Precision: 96.67 percent
# Recall: 55.77 percent
# Specificity: 92.31 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# Validation Fold 4:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 37
# Training Error : 18.14 percent
# Testing Dataset Size : 65
# Correct Decissions: 57
# Incorrect Decissions: 8
# Testing Accuracy: 92.31 percent
# Testing Error: 7.69 percent
# Precision: 100.00 percent
# Recall: 84.62 percent
# Specificity: 100.00 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 39
# Training Error : 19.12 percent
# Testing Dataset Size : 65
# Correct Decissions: 58
# Incorrect Decissions: 7
# Testing Accuracy: 93.27 percent
# Testing Error: 6.73 percent
# Precision: 100.00 percent
# Recall: 86.54 percent
# Specificity: 100.00 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 37
# Training Error : 18.14 percent
# Testing Dataset Size : 65
# Correct Decissions: 58
# Incorrect Decissions: 7
# Testing Accuracy: 93.27 percent
# Testing Error: 6.73 percent
# Precision: 100.00 percent
# Recall: 86.54 percent
# Specificity: 100.00 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 34
# Training Error : 16.67 percent
# Testing Dataset Size : 65
# Correct Decissions: 58
# Incorrect Decissions: 7
# Testing Accuracy: 93.27 percent
# Testing Error: 6.73 percent
# Precision: 100.00 percent
# Recall: 86.54 percent
# Specificity: 100.00 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 37
# Training Error : 18.14 percent
# Testing Dataset Size : 65
# Correct Decissions: 58
# Incorrect Decissions: 7
# Testing Accuracy: 93.27 percent
# Testing Error: 6.73 percent
# Precision: 100.00 percent
# Recall: 86.54 percent
# Specificity: 100.00 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 30
# Training Error : 14.71 percent
# Testing Dataset Size : 65
# Correct Decissions: 58
# Incorrect Decissions: 7
# Testing Accuracy: 93.27 percent
# Testing Error: 6.73 percent
# Precision: 100.00 percent
# Recall: 86.54 percent
# Specificity: 100.00 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 58
# Incorrect Decissions: 7
# Testing Accuracy: 93.27 percent
# Testing Error: 6.73 percent
# Precision: 100.00 percent
# Recall: 86.54 percent
# Specificity: 100.00 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 48
# Training Error : 23.53 percent
# Testing Dataset Size : 65
# Correct Decissions: 58
# Incorrect Decissions: 7
# Testing Accuracy: 93.27 percent
# Testing Error: 6.73 percent
# Precision: 100.00 percent
# Recall: 86.54 percent
# Specificity: 100.00 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 96
# Training Error : 47.06 percent
# Testing Dataset Size : 65
# Correct Decissions: 48
# Incorrect Decissions: 17
# Testing Accuracy: 83.65 percent
# Testing Error: 16.35 percent
# Precision: 100.00 percent
# Recall: 67.31 percent
# Specificity: 100.00 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# Validation Fold 5:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 34
# Training Error : 16.67 percent
# Testing Dataset Size : 65
# Correct Decissions: 55
# Incorrect Decissions: 10
# Testing Accuracy: 90.38 percent
# Testing Error: 9.62 percent
# Precision: 100.00 percent
# Recall: 80.77 percent
# Specificity: 100.00 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 29
# Training Error : 14.22 percent
# Testing Dataset Size : 65
# Correct Decissions: 56
# Incorrect Decissions: 9
# Testing Accuracy: 91.35 percent
# Testing Error: 8.65 percent
# Precision: 100.00 percent
# Recall: 82.69 percent
# Specificity: 100.00 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 36
# Training Error : 17.65 percent
# Testing Dataset Size : 65
# Correct Decissions: 56
# Incorrect Decissions: 9
# Testing Accuracy: 91.35 percent
# Testing Error: 8.65 percent
# Precision: 100.00 percent
# Recall: 82.69 percent
# Specificity: 100.00 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 37
# Training Error : 18.14 percent
# Testing Dataset Size : 65
# Correct Decissions: 56
# Incorrect Decissions: 9
# Testing Accuracy: 91.35 percent
# Testing Error: 8.65 percent
# Precision: 100.00 percent
# Recall: 82.69 percent
# Specificity: 100.00 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 30
# Training Error : 14.71 percent
# Testing Dataset Size : 65
# Correct Decissions: 56
# Incorrect Decissions: 9
# Testing Accuracy: 91.35 percent
# Testing Error: 8.65 percent
# Precision: 100.00 percent
# Recall: 82.69 percent
# Specificity: 100.00 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 32
# Training Error : 15.69 percent
# Testing Dataset Size : 65
# ...
# Recall: 84.62 percent
# Specificity: 76.92 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 35
# Training Error : 17.16 percent
# Testing Dataset Size : 65
# Correct Decissions: 54
# Incorrect Decissions: 11
# Testing Accuracy: 80.77 percent
# Testing Error: 19.23 percent
# Precision: 93.62 percent
# Recall: 84.62 percent
# Specificity: 76.92 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 54
# Incorrect Decissions: 11
# Testing Accuracy: 80.77 percent
# Testing Error: 19.23 percent
# Precision: 93.62 percent
# Recall: 84.62 percent
# Specificity: 76.92 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 35
# Training Error : 17.16 percent
# Testing Dataset Size : 65
# Correct Decissions: 54
# Incorrect Decissions: 11
# Testing Accuracy: 80.77 percent
# Testing Error: 19.23 percent
# Precision: 93.62 percent
# Recall: 84.62 percent
# Specificity: 76.92 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 33
# Training Error : 16.18 percent
# Testing Dataset Size : 65
# Correct Decissions: 54
# Incorrect Decissions: 11
# Testing Accuracy: 80.77 percent
# Testing Error: 19.23 percent
# Precision: 93.62 percent
# Recall: 84.62 percent
# Specificity: 76.92 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 34
# Training Error : 16.67 percent
# Testing Dataset Size : 65
# Correct Decissions: 54
# Incorrect Decissions: 11
# Testing Accuracy: 80.77 percent
# Testing Error: 19.23 percent
# Precision: 93.62 percent
# Recall: 84.62 percent
# Specificity: 76.92 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 44
# Training Error : 21.57 percent
# Testing Dataset Size : 65
# Correct Decissions: 55
# Incorrect Decissions: 10
# Testing Accuracy: 84.62 percent
# Testing Error: 15.38 percent
# Precision: 95.65 percent
# Recall: 84.62 percent
# Specificity: 84.62 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 93
# Training Error : 45.59 percent
# Testing Dataset Size : 65
# Correct Decissions: 48
# Incorrect Decissions: 17
# Testing Accuracy: 80.77 percent
# Testing Error: 19.23 percent
# Precision: 97.30 percent
# Recall: 69.23 percent
# Specificity: 92.31 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# Validation Fold 2:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 40
# Training Error : 19.61 percent
# Testing Dataset Size : 65
# Correct Decissions: 55
# Incorrect Decissions: 10
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 93.75 percent
# Recall: 86.54 percent
# Specificity: 76.92 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 35
# Training Error : 17.16 percent
# Testing Dataset Size : 65
# Correct Decissions: 55
# Incorrect Decissions: 10
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 93.75 percent
# Recall: 86.54 percent
# Specificity: 76.92 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 30
# Training Error : 14.71 percent
# Testing Dataset Size : 65
# Correct Decissions: 55
# Incorrect Decissions: 10
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 93.75 percent
# Recall: 86.54 percent
# Specificity: 76.92 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 35
# Training Error : 17.16 percent
# Testing Dataset Size : 65
# Correct Decissions: 55
# Incorrect Decissions: 10
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 93.75 percent
# Recall: 86.54 percent
# Specificity: 76.92 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 35
# Training Error : 17.16 percent
# Testing Dataset Size : 65
# Correct Decissions: 55
# Incorrect Decissions: 10
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 93.75 percent
# Recall: 86.54 percent
# Specificity: 76.92 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 30
# Training Error : 14.71 percent
# Testing Dataset Size : 65
# Correct Decissions: 55
# Incorrect Decissions: 10
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 93.75 percent
# Recall: 86.54 percent
# Specificity: 76.92 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 27
# Training Error : 13.24 percent
# Testing Dataset Size : 65
# Correct Decissions: 55
# Incorrect Decissions: 10
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 93.75 percent
# Recall: 86.54 percent
# Specificity: 76.92 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 42
# Training Error : 20.59 percent
# Testing Dataset Size : 65
# Correct Decissions: 54
# Incorrect Decissions: 11
# Testing Accuracy: 80.77 percent
# Testing Error: 19.23 percent
# Precision: 93.62 percent
# Recall: 84.62 percent
# Specificity: 76.92 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 92
# Training Error : 45.10 percent
# Testing Dataset Size : 65
# Correct Decissions: 54
# Incorrect Decissions: 11
# Testing Accuracy: 86.54 percent
# Testing Error: 13.46 percent
# Precision: 97.67 percent
# Recall: 80.77 percent
# Specificity: 92.31 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# Validation Fold 3:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 29
# Training Error : 14.22 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 95.35 percent
# Recall: 78.85 percent
# Specificity: 84.62 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 27
# Training Error : 13.24 percent
# Testing Dataset Size : 65
# Correct Decissions: 53
# Incorrect Decissions: 12
# Testing Accuracy: 82.69 percent
# Testing Error: 17.31 percent
# Precision: 95.45 percent
# Recall: 80.77 percent
# Specificity: 84.62 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 31
# Training Error : 15.20 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 95.35 percent
# Recall: 78.85 percent
# Specificity: 84.62 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 28
# Training Error : 13.73 percent
# Testing Dataset Size : 65
# Correct Decissions: 54
# Incorrect Decissions: 11
# Testing Accuracy: 83.65 percent
# Testing Error: 16.35 percent
# Precision: 95.56 percent
# Recall: 82.69 percent
# Specificity: 84.62 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 24
# Training Error : 11.76 percent
# Testing Dataset Size : 65
# Correct Decissions: 53
# Incorrect Decissions: 12
# Testing Accuracy: 82.69 percent
# Testing Error: 17.31 percent
# Precision: 95.45 percent
# Recall: 80.77 percent
# Specificity: 84.62 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 32
# Training Error : 15.69 percent
# Testing Dataset Size : 65
# Correct Decissions: 53
# Incorrect Decissions: 12
# Testing Accuracy: 82.69 percent
# Testing Error: 17.31 percent
# Precision: 95.45 percent
# Recall: 80.77 percent
# Specificity: 84.62 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 29
# Training Error : 14.22 percent
# Testing Dataset Size : 65
# Correct Decissions: 53
# Incorrect Decissions: 12
# Testing Accuracy: 82.69 percent
# Testing Error: 17.31 percent
# Precision: 95.45 percent
# Recall: 80.77 percent
# Specificity: 84.62 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 42
# Training Error : 20.59 percent
# Testing Dataset Size : 65
# Correct Decissions: 53
# Incorrect Decissions: 12
# Testing Accuracy: 82.69 percent
# Testing Error: 17.31 percent
# Precision: 95.45 percent
# Recall: 80.77 percent
# Specificity: 84.62 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 96
# Training Error : 47.06 percent
# Testing Dataset Size : 65
# Correct Decissions: 46
# Incorrect Decissions: 19
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 94.59 percent
# Recall: 67.31 percent
# Specificity: 84.62 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# Validation Fold 4:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 31
# Training Error : 15.20 percent
# Testing Dataset Size : 65
# Correct Decissions: 53
# Incorrect Decissions: 12
# Testing Accuracy: 82.69 percent
# Testing Error: 17.31 percent
# Precision: 95.45 percent
# Recall: 80.77 percent
# Specificity: 84.62 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 30
# Training Error : 14.71 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 95.35 percent
# Recall: 78.85 percent
# Specificity: 84.62 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 30
# Training Error : 14.71 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 80.77 percent
# Testing Error: 19.23 percent
# Precision: 95.24 percent
# Recall: 76.92 percent
# Specificity: 84.62 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 27
# Training Error : 13.24 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 95.35 percent
# Recall: 78.85 percent
# Specificity: 84.62 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 27
# Training Error : 13.24 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 95.35 percent
# Recall: 78.85 percent
# Specificity: 84.62 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 38
# Training Error : 18.63 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 95.35 percent
# Recall: 78.85 percent
# Specificity: 84.62 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 36
# Training Error : 17.65 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 95.35 percent
# Recall: 78.85 percent
# Specificity: 84.62 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 46
# Training Error : 22.55 percent
# Testing Dataset Size : 65
# Correct Decissions: 52
# Incorrect Decissions: 13
# Testing Accuracy: 81.73 percent
# Testing Error: 18.27 percent
# Precision: 95.35 percent
# Recall: 78.85 percent
# Specificity: 84.62 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 94
# Training Error : 46.08 percent
# Testing Dataset Size : 65
# Correct Decissions: 43
# Incorrect Decissions: 22
# Testing Accuracy: 75.96 percent
# Testing Error: 24.04 percent
# Precision: 96.87 percent
# Recall: 59.62 percent
# Specificity: 92.31 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
#
# Validation Fold 5:
# Nu : 0.001000
# Training Dataset Size : 204
# No of Training Misclassifications : 39
# Training Error : 19.12 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.002154
# Training Dataset Size : 204
# No of Training Misclassifications : 31
# Training Error : 15.20 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.004642
# Training Dataset Size : 204
# No of Training Misclassifications : 34
# Training Error : 16.67 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.010000
# Training Dataset Size : 204
# No of Training Misclassifications : 31
# Training Error : 15.20 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.021544
# Training Dataset Size : 204
# No of Training Misclassifications : 32
# Training Error : 15.69 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.046416
# Training Dataset Size : 204
# No of Training Misclassifications : 30
# Training Error : 14.71 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.100000
# Training Dataset Size : 204
# No of Training Misclassifications : 28
# Training Error : 13.73 percent
# Testing Dataset Size : 65
# Correct Decissions: 51
# Incorrect Decissions: 14
# Testing Accuracy: 77.88 percent
# Testing Error: 22.12 percent
# Precision: 93.18 percent
# Recall: 78.85 percent
# Specificity: 76.92 percent
#
# Nu : 0.215443
# Training Dataset Size : 204
# No of Training Misclassifications : 45
# Training Error : 22.06 percent
# Testing Dataset Size : 65
# Correct Decissions: 50
# Incorrect Decissions: 15
# Testing Accuracy: 76.92 percent
# Testing Error: 23.08 percent
# Precision: 93.02 percent
# Recall: 76.92 percent
# Specificity: 76.92 percent
#
# Nu : 0.464159
# Training Dataset Size : 204
# No of Training Misclassifications : 93
# Training Error : 45.59 percent
# Testing Dataset Size : 65
# Correct Decissions: 39
# Incorrect Decissions: 26
# Testing Accuracy: 69.23 percent
# Testing Error: 30.77 percent
# Precision: 93.33 percent
# Recall: 53.85 percent
# Specificity: 84.62 percent
#
# Nu : 1.000000
# Training Dataset Size : 204
# No of Training Misclassifications : 204
# Training Error : 100.00 percent
# Testing Dataset Size : 65
# Correct Decissions: 13
# Incorrect Decissions: 52
# Testing Accuracy: 50.00 percent
# Testing Error: 50.00 percent
# Precision: 0.00 percent
# Recall: 0.00 percent
# Specificity: 100.00 percent
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:263: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
